# %%
import time
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, 28*28).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28*28).astype('float32') / 255.0
y_train = y_train.astype('int64')
y_test = y_test.astype('int64')

# Parameters
activations = ['sigmoid', 'tanh', 'relu']
hidden_layer_sizes = [256, 128, 64]
learning_rate = 0.1 
batch_size = 10 
epochs = 50 

# Activation functions in TensorFlow
def activate(x, activation):
    if activation == 'sigmoid':
        return tf.nn.sigmoid(x)
    elif activation == 'tanh':
        return tf.nn.tanh(x)
    elif activation == 'relu':
        return tf.nn.relu(x)

# Initialize weights and biases using TensorFlow variables
def initialize_parameters(input_size, hidden_size, output_size):
    initializer = tf.initializers.GlorotUniform()
    W1 = tf.Variable(initializer([input_size, hidden_size]))
    b1 = tf.Variable(tf.zeros([hidden_size]))
    W2 = tf.Variable(initializer([hidden_size, output_size]))
    b2 = tf.Variable(tf.zeros([output_size]))
    return W1, b1, W2, b2

# Forward pass
def forward_pass(x, W1, b1, W2, b2, activation):
    Z1 = tf.add(tf.matmul(x, W1), b1)
    A1 = activate(Z1, activation)
    Z2 = tf.add(tf.matmul(A1, W2), b2)
    return Z2

# Train model using TensorFlow
def train_model(x_train, y_train, x_test, y_test, activation, hidden_size):
    input_size = 784
    output_size = 10
    W1, b1, W2, b2 = initialize_parameters(input_size, hidden_size, output_size)
    optimizer = tf.optimizers.Adam(learning_rate)

    losses = []
    accuracies = []
    start_time = time.time()

    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")
        for i in range(0, len(x_train), batch_size):
            x_batch = x_train[i:i+batch_size]
            y_batch = y_train[i:i+batch_size]

            with tf.GradientTape() as tape:
                logits = forward_pass(x_batch, W1, b1, W2, b2, activation)
                loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y_batch, logits=logits))

            gradients = tape.gradient(loss, [W1, b1, W2, b2])
            optimizer.apply_gradients(zip(gradients, [W1, b1, W2, b2]))

        losses.append(loss.numpy())

        # Accuracy calculation
        logits_train = forward_pass(x_train, W1, b1, W2, b2, activation)
        predictions = np.argmax(logits_train.numpy(), axis=1)
        accuracy = accuracy_score(y_train, predictions)
        accuracies.append(accuracy)
        print(f"Epoch {epoch+1} Accuracy: {accuracy:.4f}")

    time_taken = time.time() - start_time

    # Test accuracy
    logits_test = forward_pass(x_test, W1, b1, W2, b2, activation)
    y_pred = np.argmax(logits_test.numpy(), axis=1)

    # Plot Results
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(losses, label='Loss')
    plt.title(f'{activation} | Hidden Size: {hidden_size} | Loss Curve')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(accuracies, label='Accuracy')
    plt.title(f'{activation} | Hidden Size: {hidden_size} | Accuracy Curve')
    plt.legend()
    plt.show()

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{activation} | Hidden Size: {hidden_size} | Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    print(f"Activation: {activation}, Hidden Size: {hidden_size}, Test Accuracy: {accuracy_score(y_test, y_pred):.4f}, Time Taken: {time_taken:.2f} seconds")

# Run training for all combinations
for activation in activations:
    for hidden_size in hidden_layer_sizes:
        train_model(x_train, y_train, x_test, y_test, activation, hidden_size)

print("Evaluation completed.")
# Out:
# Epoch 1/50
# Epoch 1 Accuracy: 0.7387
# Epoch 2/50
# Epoch 2 Accuracy: 0.7592
# Epoch 3/50
# Epoch 3 Accuracy: 0.7399
# Epoch 4/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 113
#     111 for activation in activations:
#     112     for hidden_size in hidden_layer_sizes:
# --> 113         train_model(x_train, y_train, x_test, y_test, activation, hidden_size)
#     115 print("Evaluation completed.")
#
# Cell In[1], line 65, in train_model(x_train, y_train, x_test, y_test, activation, hidden_size)
#      62 y_batch = y_train[i:i+batch_size]
#      64 with tf.GradientTape() as tape:
# ---> 65     logits = forward_pass(x_batch, W1, b1, W2, b2, activation)
#      66     loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y_batch, logits=logits))
#      68 gradients = tape.gradient(loss, [W1, b1, W2, b2])
#
# Cell In[1], line 42, in forward_pass(x, W1, b1, W2, b2, activation)
#      41 def forward_pass(x, W1, b1, W2, b2, activation):
# ---> 42     Z1 = tf.add(tf.matmul(x, W1), b1)
#      43     A1 = activate(Z1, activation)
#      44     Z2 = tf.add(tf.matmul(A1, W2), b2)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\math_ops.py:3915, in add(x, y, name)
#    3913 with ops.name_scope(name, "Add", [x]) as name:
#    3914   x = ops.convert_to_tensor(x, name="x")
# -> 3915   y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    3916   if x.dtype == dtypes.string:
#    3917     return gen_math_ops.add(x, y, name=name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:217, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     215 if dtype is None and preferred_dtype is not None:
#     216   try:
# --> 217     ret = conversion_func(
#     218         value, dtype=preferred_dtype, name=name, as_ref=as_ref)
#     219   except (TypeError, ValueError):
#     220     # Could not coerce the conversion to use the preferred dtype.
#     221     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2375, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2374 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2375   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1621, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1619   return self.read_value().op.inputs[0]
#    1620 else:
# -> 1621   return self.value()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:656, in BaseResourceVariable.value(self)
#     654   return self._cached_value
#     655 with ops.colocate_with(None, ignore_existing=True):
# --> 656   return self._read_variable_op()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:841, in BaseResourceVariable._read_variable_op(self, no_copy)
#     839       result = read_and_set_handle(no_copy)
#     840 else:
# --> 841   result = read_and_set_handle(no_copy)
#     843 if not context.executing_eagerly():
#     844   # Note that if a control flow context is active the input of the read op
#     845   # might not actually be the handle. This line bypasses it.
#     846   record.record_operation(
#     847       "ReadVariableOp", [result], [self.handle],
#     848       backward_function=lambda x: [x],
#     849       forward_function=lambda x: [x])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:831, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     829 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     830   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 831 result = gen_resource_variable_ops.read_variable_op(
#     832     self.handle, self._dtype)
#     833 _maybe_set_handle_data(self._dtype, self.handle, result)
#     834 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:590, in read_variable_op(resource, dtype, name)
#     588 if tld.is_eager:
#     589   try:
# --> 590     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     591       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     592     return _result
#     593   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
